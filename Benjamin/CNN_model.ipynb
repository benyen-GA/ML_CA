# %%
import torch
import numpy as np
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.utils.data import random_split

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from sklearn.metrics import classification_report, confusion_matrix

# %%
transform_train = transforms.Compose([
    transforms.Resize((100,100)),
    transforms.ToTensor(),
    transforms.RandomHorizontalFlip(),        # Randomly flip images horizontally for augmentation
    transforms.RandomRotation(15),
    transforms.Normalize(mean = [0.5]*3, std = [0.5]*3)
])

transform_test = transforms.Compose([
    transforms.Resize((100,100)),
    transforms.ToTensor(),
    transforms.Normalize(mean = [0.5]*3, std = [0.5]*3)
])

# %%
train_dataset = datasets.ImageFolder(root = './train/',transform = transform_train)
test_dataset = datasets.ImageFolder(root = './test/',transform = transform_test)

train_size = int(0.7 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])

# %%
def batch(batchsize):
    
    train_loader = DataLoader(train_dataset, batch_size=batchsize, shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=batchsize, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batchsize, shuffle=False)

    return train_loader, val_loader, test_loader

def create_cnn_model(filter_config):
    class CustomCNN(nn.Module):
        def __init__(self):
            super(CustomCNN, self).__init__()
            f1, f2, f3 = filter_config
            self.f3 = f3 
            self.conv1 = nn.Conv2d(3, f1, 3, padding=1)
            self.conv2 = nn.Conv2d(f1, f2, 3, padding=1)
            self.conv3 = nn.Conv2d(f2, f3, 3, padding=1)
            self.pool = nn.MaxPool2d(2, 2)
            self.dropout = nn.Dropout(0.3)
            self.fc1 = nn.Linear(f3 * 12 * 12, 128)
            self.fc2 = nn.Linear(128, 4)

        def forward(self, x):
            x = self.pool(F.relu(self.conv1(x)))
            x = self.pool(F.relu(self.conv2(x)))
            x = self.pool(F.relu(self.conv3(x)))
            x = x.view(-1, self.f3 * 12 * 12)
            x = self.dropout(F.relu(self.fc1(x)))
            x = self.fc2(x)
            return x

    return CustomCNN()

def train_model(model, criterion, optimizer, train_loader, num_epochs=10):
    model.train()
    for epoch in range(num_epochs):
        running_loss = 0.0
        correct = 0
        total = 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
        acc = 100. * correct / total
        print(f"Epoch {epoch+1}, Loss: {running_loss:.4f}, Accuracy: {acc:.2f}%")

def full_evaluation(model, loader, dataset_name):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    print(f"\n {dataset_name} Evaluation")
    print("-" * 40)
    print("Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=test_dataset.classes))
    print("Confusion Matrix:")
    print(confusion_matrix(all_labels, all_preds))

# %%
configs = [
    ([32, 64, 128], "Run 1"),
    ([32, 64, 64],  "Run 2"),
    ([16, 32, 64],  "Run 3"),
    ([64, 64, 64],  "Run 4"),
    ([128, 128, 128], "Run 5"),
    ([32, 32, 32],  "Run 6"),
]

batch_sizes = [16, 32, 64]

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for filters, label in configs:
    for bsz in batch_sizes:
        train_loader, val_loader, test_loader = batch(bsz)
        
        print(f"\n{label} {filters} (Batch size: {bsz})\n{'-' * 30}")
        model = create_cnn_model(filters).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=0.001)
        
        train_model(model, criterion, optimizer, train_loader)
        full_evaluation(model, val_loader, "Validation Set")
        full_evaluation(model, test_loader, "Test Set")
        
        print('-' * 50)
# Out:
# Run 1 [32, 64, 128] (Batch size: 16)
# ------------------------------
# Epoch 1, Loss: 57.0301, Accuracy: 47.50%
# Epoch 2, Loss: 37.8145, Accuracy: 71.25%
# Epoch 3, Loss: 30.4358, Accuracy: 78.62%
# Epoch 4, Loss: 26.2018, Accuracy: 81.62%
# Epoch 5, Loss: 23.2500, Accuracy: 82.75%
# Epoch 6, Loss: 20.9434, Accuracy: 85.62%
# Epoch 7, Loss: 20.3382, Accuracy: 85.12%
# Epoch 8, Loss: 19.6672, Accuracy: 86.88%
# Epoch 9, Loss: 17.3744, Accuracy: 88.12%
# Epoch 10, Loss: 16.4521, Accuracy: 89.62%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.95      0.93      0.94        61
#       banana       0.84      0.92      0.88        52
#        mixed       0.96      0.88      0.92        58
#       orange       0.93      0.94      0.94        69
#
#     accuracy                           0.92       240
#    macro avg       0.92      0.92      0.92       240
# weighted avg       0.92      0.92      0.92       240
#
# Confusion Matrix:
# [[57  3  0  1]
#  [ 1 48  1  2]
#  [ 1  4 51  2]
#  [ 1  2  1 65]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.94      0.83      0.88        18
#        mixed       0.57      0.80      0.67         5
#       orange       0.89      0.94      0.92        18
#
#     accuracy                           0.88        60
#    macro avg       0.84      0.87      0.85        60
# weighted avg       0.90      0.88      0.89        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 15  1  1]
#  [ 0  0  4  1]
#  [ 0  1  0 17]]
# --------------------------------------------------
#
# Run 1 [32, 64, 128] (Batch size: 32)
# ------------------------------
# Epoch 1, Loss: 29.7703, Accuracy: 46.00%
# Epoch 2, Loss: 20.2831, Accuracy: 67.50%
# Epoch 3, Loss: 16.0556, Accuracy: 76.25%
# Epoch 4, Loss: 12.2623, Accuracy: 81.00%
# Epoch 5, Loss: 11.7648, Accuracy: 85.25%
# Epoch 6, Loss: 11.9770, Accuracy: 84.50%
# Epoch 7, Loss: 10.8975, Accuracy: 84.38%
# Epoch 8, Loss: 7.9623, Accuracy: 88.75%
# Epoch 9, Loss: 8.8271, Accuracy: 88.88%
# Epoch 10, Loss: 7.5418, Accuracy: 90.12%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.97      0.92      0.94        61
#       banana       0.80      0.98      0.88        52
#        mixed       0.81      0.90      0.85        58
#       orange       0.96      0.75      0.85        69
#
#     accuracy                           0.88       240
#    macro avg       0.88      0.89      0.88       240
# weighted avg       0.89      0.88      0.88       240
#
# Confusion Matrix:
# [[56  3  1  1]
#  [ 1 51  0  0]
#  [ 0  5 52  1]
#  [ 1  5 11 52]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.94      0.94      0.94        18
#        mixed       0.42      1.00      0.59         5
#       orange       1.00      0.67      0.80        18
#
#     accuracy                           0.85        60
#    macro avg       0.83      0.88      0.81        60
# weighted avg       0.92      0.85      0.86        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 17  0  0]
#  [ 0  0  5  0]
#  [ 0  1  5 12]]
# --------------------------------------------------
#
# Run 1 [32, 64, 128] (Batch size: 64)
# ------------------------------
# Epoch 1, Loss: 17.6147, Accuracy: 35.50%
# Epoch 2, Loss: 12.2507, Accuracy: 65.00%
# Epoch 3, Loss: 10.8506, Accuracy: 68.12%
# Epoch 4, Loss: 8.5612, Accuracy: 78.12%
# Epoch 5, Loss: 7.2998, Accuracy: 80.25%
# Epoch 6, Loss: 5.9689, Accuracy: 82.88%
# Epoch 7, Loss: 5.7525, Accuracy: 84.75%
# Epoch 8, Loss: 4.8897, Accuracy: 86.75%
# Epoch 9, Loss: 5.0770, Accuracy: 85.88%
# Epoch 10, Loss: 5.5530, Accuracy: 83.62%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.96      0.90      0.93        61
#       banana       0.80      0.92      0.86        52
#        mixed       0.92      0.76      0.83        58
#       orange       0.84      0.91      0.88        69
#
#     accuracy                           0.88       240
#    macro avg       0.88      0.87      0.87       240
# weighted avg       0.88      0.88      0.87       240
#
# Confusion Matrix:
# [[55  3  1  2]
#  [ 0 48  0  4]
#  [ 1  7 44  6]
#  [ 1  2  3 63]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.94      0.89      0.91        18
#        mixed       0.57      0.80      0.67         5
#       orange       0.94      0.94      0.94        18
#
#     accuracy                           0.90        60
#    macro avg       0.85      0.88      0.86        60
# weighted avg       0.91      0.90      0.90        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 16  1  0]
#  [ 0  0  4  1]
#  [ 0  1  0 17]]
# --------------------------------------------------
#
# Run 2 [32, 64, 64] (Batch size: 16)
# ------------------------------
# Epoch 1, Loss: 58.8548, Accuracy: 47.62%
# Epoch 2, Loss: 38.9369, Accuracy: 70.88%
# Epoch 3, Loss: 30.9948, Accuracy: 79.12%
# Epoch 4, Loss: 26.6880, Accuracy: 81.75%
# Epoch 5, Loss: 24.0235, Accuracy: 83.25%
# Epoch 6, Loss: 20.9887, Accuracy: 84.50%
# Epoch 7, Loss: 21.3609, Accuracy: 84.12%
# Epoch 8, Loss: 17.5924, Accuracy: 88.00%
# Epoch 9, Loss: 17.1870, Accuracy: 88.12%
# Epoch 10, Loss: 14.7453, Accuracy: 90.00%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.97      0.95      0.96        61
#       banana       0.91      0.96      0.93        52
#        mixed       0.96      0.91      0.94        58
#       orange       0.93      0.94      0.94        69
#
#     accuracy                           0.94       240
#    macro avg       0.94      0.94      0.94       240
# weighted avg       0.94      0.94      0.94       240
#
# Confusion Matrix:
# [[58  2  0  1]
#  [ 0 50  0  2]
#  [ 1  2 53  2]
#  [ 1  1  2 65]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.94      0.89      0.91        18
#        mixed       0.67      0.80      0.73         5
#       orange       0.89      0.94      0.92        18
#
#     accuracy                           0.90        60
#    macro avg       0.86      0.88      0.87        60
# weighted avg       0.91      0.90      0.90        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 16  0  1]
#  [ 0  0  4  1]
#  [ 0  1  0 17]]
# --------------------------------------------------
#
# Run 2 [32, 64, 64] (Batch size: 32)
# ------------------------------
# Epoch 1, Loss: 29.1635, Accuracy: 49.00%
# Epoch 2, Loss: 18.7224, Accuracy: 70.50%
# Epoch 3, Loss: 15.2774, Accuracy: 77.38%
# Epoch 4, Loss: 13.3607, Accuracy: 81.62%
# Epoch 5, Loss: 12.8813, Accuracy: 81.50%
# Epoch 6, Loss: 11.3283, Accuracy: 85.00%
# Epoch 7, Loss: 11.4663, Accuracy: 84.50%
# Epoch 8, Loss: 10.6205, Accuracy: 84.88%
# Epoch 9, Loss: 8.8583, Accuracy: 88.62%
# Epoch 10, Loss: 8.0802, Accuracy: 89.12%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.88      0.97      0.92        61
#       banana       0.82      0.96      0.88        52
#        mixed       0.82      0.84      0.83        58
#       orange       1.00      0.75      0.86        69
#
#     accuracy                           0.88       240
#    macro avg       0.88      0.88      0.87       240
# weighted avg       0.89      0.88      0.87       240
#
# Confusion Matrix:
# [[59  2  0  0]
#  [ 1 50  1  0]
#  [ 5  4 49  0]
#  [ 2  5 10 52]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.94      0.94      0.94        18
#        mixed       0.38      1.00      0.56         5
#       orange       1.00      0.61      0.76        18
#
#     accuracy                           0.83        60
#    macro avg       0.82      0.86      0.79        60
# weighted avg       0.91      0.83      0.85        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 17  0  0]
#  [ 0  0  5  0]
#  [ 0  1  6 11]]
# --------------------------------------------------
#
# Run 2 [32, 64, 64] (Batch size: 64)
# ------------------------------
# Epoch 1, Loss: 16.6650, Accuracy: 36.62%
# Epoch 2, Loss: 13.0551, Accuracy: 55.12%
# Epoch 3, Loss: 9.5147, Accuracy: 71.25%
# Epoch 4, Loss: 7.6382, Accuracy: 77.88%
# Epoch 5, Loss: 6.6781, Accuracy: 81.88%
# Epoch 6, Loss: 6.2320, Accuracy: 83.38%
# Epoch 7, Loss: 5.9296, Accuracy: 84.12%
# Epoch 8, Loss: 5.6291, Accuracy: 84.25%
# Epoch 9, Loss: 5.3921, Accuracy: 86.75%
# Epoch 10, Loss: 4.8489, Accuracy: 86.75%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.91      0.98      0.94        61
#       banana       0.86      0.85      0.85        52
#        mixed       0.91      0.83      0.86        58
#       orange       0.90      0.91      0.91        69
#
#     accuracy                           0.90       240
#    macro avg       0.89      0.89      0.89       240
# weighted avg       0.90      0.90      0.89       240
#
# Confusion Matrix:
# [[60  1  0  0]
#  [ 1 44  3  4]
#  [ 3  4 48  3]
#  [ 2  2  2 63]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.89      0.89      0.89        19
#       banana       0.94      0.89      0.91        18
#        mixed       0.50      0.60      0.55         5
#       orange       0.89      0.89      0.89        18
#
#     accuracy                           0.87        60
#    macro avg       0.81      0.82      0.81        60
# weighted avg       0.87      0.87      0.87        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 16  0  1]
#  [ 1  0  3  1]
#  [ 0  1  1 16]]
# --------------------------------------------------
#
# Run 3 [16, 32, 64] (Batch size: 16)
# ------------------------------
# Epoch 1, Loss: 56.9007, Accuracy: 48.75%
# Epoch 2, Loss: 39.0653, Accuracy: 70.88%
# Epoch 3, Loss: 29.4390, Accuracy: 79.25%
# Epoch 4, Loss: 26.5789, Accuracy: 82.38%
# Epoch 5, Loss: 23.4118, Accuracy: 84.38%
# Epoch 6, Loss: 20.2086, Accuracy: 86.50%
# Epoch 7, Loss: 19.4753, Accuracy: 85.75%
# Epoch 8, Loss: 16.2698, Accuracy: 90.00%
# Epoch 9, Loss: 14.9740, Accuracy: 89.62%
# Epoch 10, Loss: 16.4999, Accuracy: 88.75%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.98      0.87      0.92        61
#       banana       0.81      0.88      0.84        52
#        mixed       0.88      0.88      0.88        58
#       orange       0.93      0.96      0.94        69
#
#     accuracy                           0.90       240
#    macro avg       0.90      0.90      0.90       240
# weighted avg       0.90      0.90      0.90       240
#
# Confusion Matrix:
# [[53  3  3  2]
#  [ 0 46  3  3]
#  [ 0  7 51  0]
#  [ 1  1  1 66]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.94      0.89      0.91        18
#        mixed       0.42      1.00      0.59         5
#       orange       1.00      0.72      0.84        18
#
#     accuracy                           0.85        60
#    macro avg       0.83      0.88      0.82        60
# weighted avg       0.92      0.85      0.87        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 16  1  0]
#  [ 0  0  5  0]
#  [ 0  1  4 13]]
# --------------------------------------------------
#
# Run 3 [16, 32, 64] (Batch size: 32)
# ------------------------------
# Epoch 1, Loss: 31.5625, Accuracy: 39.00%
# Epoch 2, Loss: 24.1875, Accuracy: 60.88%
# Epoch 3, Loss: 17.9086, Accuracy: 74.50%
# Epoch 4, Loss: 14.6844, Accuracy: 79.25%
# Epoch 5, Loss: 13.0798, Accuracy: 81.38%
# Epoch 6, Loss: 12.4854, Accuracy: 82.12%
# Epoch 7, Loss: 10.8302, Accuracy: 85.75%
# Epoch 8, Loss: 9.3595, Accuracy: 86.62%
# Epoch 9, Loss: 8.9156, Accuracy: 87.62%
# Epoch 10, Loss: 7.5446, Accuracy: 89.12%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.91      0.95      0.93        61
#       banana       0.80      0.94      0.87        52
#        mixed       0.94      0.84      0.89        58
#       orange       0.97      0.88      0.92        69
#
#     accuracy                           0.90       240
#    macro avg       0.91      0.91      0.90       240
# weighted avg       0.91      0.90      0.90       240
#
# Confusion Matrix:
# [[58  2  0  1]
#  [ 1 49  1  1]
#  [ 3  6 49  0]
#  [ 2  4  2 61]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.94      0.83      0.88        18
#        mixed       0.44      0.80      0.57         5
#       orange       0.94      0.89      0.91        18
#
#     accuracy                           0.87        60
#    macro avg       0.82      0.85      0.82        60
# weighted avg       0.90      0.87      0.88        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 15  2  0]
#  [ 0  0  4  1]
#  [ 0  1  1 16]]
# --------------------------------------------------
#
# Run 3 [16, 32, 64] (Batch size: 64)
# ------------------------------
# Epoch 1, Loss: 17.3440, Accuracy: 36.25%
# Epoch 2, Loss: 14.0426, Accuracy: 53.38%
# Epoch 3, Loss: 11.3497, Accuracy: 67.75%
# Epoch 4, Loss: 9.0805, Accuracy: 74.88%
# Epoch 5, Loss: 7.8133, Accuracy: 78.25%
# Epoch 6, Loss: 7.0959, Accuracy: 80.38%
# Epoch 7, Loss: 6.2302, Accuracy: 81.88%
# Epoch 8, Loss: 6.0896, Accuracy: 83.00%
# Epoch 9, Loss: 5.4873, Accuracy: 85.25%
# Epoch 10, Loss: 5.0031, Accuracy: 86.50%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.93      0.93      0.93        61
#       banana       0.83      0.83      0.83        52
#        mixed       0.92      0.84      0.88        58
#       orange       0.85      0.91      0.88        69
#
#     accuracy                           0.88       240
#    macro avg       0.88      0.88      0.88       240
# weighted avg       0.88      0.88      0.88       240
#
# Confusion Matrix:
# [[57  2  1  1]
#  [ 1 43  1  7]
#  [ 2  4 49  3]
#  [ 1  3  2 63]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       1.00      0.89      0.94        18
#        mixed       0.57      0.80      0.67         5
#       orange       0.89      0.94      0.92        18
#
#     accuracy                           0.90        60
#    macro avg       0.85      0.88      0.86        60
# weighted avg       0.92      0.90      0.90        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 16  0  1]
#  [ 0  0  4  1]
#  [ 0  0  1 17]]
# --------------------------------------------------
#
# Run 4 [64, 64, 64] (Batch size: 16)
# ------------------------------
# Epoch 1, Loss: 50.8157, Accuracy: 56.75%
# Epoch 2, Loss: 33.6782, Accuracy: 77.75%
# Epoch 3, Loss: 29.5970, Accuracy: 78.38%
# Epoch 4, Loss: 26.8084, Accuracy: 81.12%
# Epoch 5, Loss: 23.6478, Accuracy: 83.25%
# Epoch 6, Loss: 21.4354, Accuracy: 85.50%
# Epoch 7, Loss: 17.9735, Accuracy: 87.38%
# Epoch 8, Loss: 16.6011, Accuracy: 89.25%
# Epoch 9, Loss: 15.3492, Accuracy: 89.38%
# Epoch 10, Loss: 14.7974, Accuracy: 89.62%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.94      0.97      0.95        61
#       banana       0.85      0.96      0.90        52
#        mixed       0.86      0.93      0.89        58
#       orange       0.98      0.78      0.87        69
#
#     accuracy                           0.90       240
#    macro avg       0.91      0.91      0.90       240
# weighted avg       0.91      0.90      0.90       240
#
# Confusion Matrix:
# [[59  1  1  0]
#  [ 1 50  0  1]
#  [ 1  3 54  0]
#  [ 2  5  8 54]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.94      0.83      0.88        18
#        mixed       0.42      1.00      0.59         5
#       orange       1.00      0.78      0.88        18
#
#     accuracy                           0.85        60
#    macro avg       0.82      0.88      0.82        60
# weighted avg       0.92      0.85      0.87        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 15  2  0]
#  [ 0  0  5  0]
#  [ 0  1  3 14]]
# --------------------------------------------------
#
# Run 4 [64, 64, 64] (Batch size: 32)
# ------------------------------
# Epoch 1, Loss: 26.8565, Accuracy: 51.62%
# Epoch 2, Loss: 16.7726, Accuracy: 76.00%
# Epoch 3, Loss: 15.4663, Accuracy: 78.50%
# Epoch 4, Loss: 13.9633, Accuracy: 80.88%
# Epoch 5, Loss: 10.7211, Accuracy: 85.62%
# Epoch 6, Loss: 10.6977, Accuracy: 86.25%
# Epoch 7, Loss: 9.9149, Accuracy: 84.75%
# Epoch 8, Loss: 9.1344, Accuracy: 87.88%
# Epoch 9, Loss: 8.6994, Accuracy: 87.25%
# Epoch 10, Loss: 6.8175, Accuracy: 90.25%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       1.00      0.75      0.86        61
#       banana       0.81      0.92      0.86        52
#        mixed       0.72      0.88      0.79        58
#       orange       0.89      0.83      0.86        69
#
#     accuracy                           0.84       240
#    macro avg       0.86      0.85      0.84       240
# weighted avg       0.86      0.84      0.84       240
#
# Confusion Matrix:
# [[46  3  8  4]
#  [ 0 48  2  2]
#  [ 0  6 51  1]
#  [ 0  2 10 57]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.94      0.89      0.91        18
#        mixed       0.45      1.00      0.62         5
#       orange       1.00      0.78      0.88        18
#
#     accuracy                           0.87        60
#    macro avg       0.84      0.89      0.83        60
# weighted avg       0.92      0.87      0.88        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 16  1  0]
#  [ 0  0  5  0]
#  [ 0  1  3 14]]
# --------------------------------------------------
#
# Run 4 [64, 64, 64] (Batch size: 64)
# ------------------------------
# Epoch 1, Loss: 16.6652, Accuracy: 39.00%
# Epoch 2, Loss: 10.2609, Accuracy: 69.00%
# Epoch 3, Loss: 8.2832, Accuracy: 75.50%
# Epoch 4, Loss: 8.2159, Accuracy: 77.38%
# Epoch 5, Loss: 6.8040, Accuracy: 82.50%
# Epoch 6, Loss: 5.7070, Accuracy: 85.50%
# Epoch 7, Loss: 4.8892, Accuracy: 87.50%
# Epoch 8, Loss: 4.4752, Accuracy: 87.75%
# Epoch 9, Loss: 4.0599, Accuracy: 88.62%
# Epoch 10, Loss: 4.5515, Accuracy: 87.00%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.90      0.90      0.90        61
#       banana       0.76      0.98      0.86        52
#        mixed       0.84      0.81      0.82        58
#       orange       0.98      0.80      0.88        69
#
#     accuracy                           0.87       240
#    macro avg       0.87      0.87      0.87       240
# weighted avg       0.88      0.87      0.87       240
#
# Confusion Matrix:
# [[55  3  3  0]
#  [ 0 51  0  1]
#  [ 4  7 47  0]
#  [ 2  6  6 55]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.94      0.94      0.94        18
#        mixed       0.50      0.80      0.62         5
#       orange       0.94      0.83      0.88        18
#
#     accuracy                           0.88        60
#    macro avg       0.83      0.87      0.84        60
# weighted avg       0.91      0.88      0.89        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 17  0  0]
#  [ 0  0  4  1]
#  [ 0  1  2 15]]
# --------------------------------------------------
#
# Run 5 [128, 128, 128] (Batch size: 16)
# ------------------------------
# Epoch 1, Loss: 57.5154, Accuracy: 47.50%
# Epoch 2, Loss: 41.2481, Accuracy: 67.25%
# Epoch 3, Loss: 35.2081, Accuracy: 74.00%
# Epoch 4, Loss: 26.8558, Accuracy: 80.88%
# Epoch 5, Loss: 22.5132, Accuracy: 84.50%
# Epoch 6, Loss: 21.7080, Accuracy: 85.38%
# Epoch 7, Loss: 19.3154, Accuracy: 85.50%
# Epoch 8, Loss: 16.4147, Accuracy: 88.12%
# Epoch 9, Loss: 15.4705, Accuracy: 88.62%
# Epoch 10, Loss: 13.0405, Accuracy: 91.50%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.88      0.97      0.92        61
#       banana       0.80      0.98      0.88        52
#        mixed       0.74      0.90      0.81        58
#       orange       1.00      0.57      0.72        69
#
#     accuracy                           0.84       240
#    macro avg       0.86      0.85      0.83       240
# weighted avg       0.86      0.84      0.83       240
#
# Confusion Matrix:
# [[59  1  1  0]
#  [ 0 51  1  0]
#  [ 1  5 52  0]
#  [ 7  7 16 39]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.89      0.89      0.89        19
#       banana       0.94      0.89      0.91        18
#        mixed       0.29      1.00      0.45         5
#       orange       1.00      0.39      0.56        18
#
#     accuracy                           0.75        60
#    macro avg       0.78      0.79      0.71        60
# weighted avg       0.89      0.75      0.76        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 16  1  0]
#  [ 0  0  5  0]
#  [ 1  1  9  7]]
# --------------------------------------------------
#
# Run 5 [128, 128, 128] (Batch size: 32)
# ------------------------------
# Epoch 1, Loss: 31.3186, Accuracy: 43.25%
# Epoch 2, Loss: 20.1916, Accuracy: 68.38%
# Epoch 3, Loss: 16.2416, Accuracy: 77.25%
# Epoch 4, Loss: 12.8239, Accuracy: 82.00%
# Epoch 5, Loss: 12.1295, Accuracy: 82.88%
# Epoch 6, Loss: 12.9884, Accuracy: 83.12%
# Epoch 7, Loss: 9.2525, Accuracy: 85.75%
# Epoch 8, Loss: 9.0025, Accuracy: 86.25%
# Epoch 9, Loss: 9.5764, Accuracy: 86.12%
# Epoch 10, Loss: 7.6796, Accuracy: 89.25%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.97      0.95      0.96        61
#       banana       0.85      0.90      0.88        52
#        mixed       0.91      0.88      0.89        58
#       orange       0.93      0.93      0.93        69
#
#     accuracy                           0.92       240
#    macro avg       0.91      0.92      0.91       240
# weighted avg       0.92      0.92      0.92       240
#
# Confusion Matrix:
# [[58  2  1  0]
#  [ 0 47  1  4]
#  [ 1  5 51  1]
#  [ 1  1  3 64]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.94      0.83      0.88        18
#        mixed       0.50      0.80      0.62         5
#       orange       0.89      0.89      0.89        18
#
#     accuracy                           0.87        60
#    macro avg       0.82      0.85      0.83        60
# weighted avg       0.89      0.87      0.87        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 15  1  1]
#  [ 0  0  4  1]
#  [ 0  1  1 16]]
# --------------------------------------------------
#
# Run 5 [128, 128, 128] (Batch size: 64)
# ------------------------------
# Epoch 1, Loss: 17.2880, Accuracy: 37.25%
# Epoch 2, Loss: 11.7623, Accuracy: 63.62%
# Epoch 3, Loss: 9.7193, Accuracy: 73.00%
# Epoch 4, Loss: 8.4440, Accuracy: 77.75%
# Epoch 5, Loss: 7.3496, Accuracy: 80.25%
# Epoch 6, Loss: 6.4773, Accuracy: 82.38%
# Epoch 7, Loss: 6.0530, Accuracy: 84.38%
# Epoch 8, Loss: 6.1563, Accuracy: 84.00%
# Epoch 9, Loss: 5.0254, Accuracy: 86.00%
# Epoch 10, Loss: 4.7973, Accuracy: 86.25%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.95      0.90      0.92        61
#       banana       0.80      0.83      0.81        52
#        mixed       0.95      0.69      0.80        58
#       orange       0.77      0.96      0.85        69
#
#     accuracy                           0.85       240
#    macro avg       0.87      0.84      0.85       240
# weighted avg       0.86      0.85      0.85       240
#
# Confusion Matrix:
# [[55  3  1  2]
#  [ 1 43  1  7]
#  [ 1  6 40 11]
#  [ 1  2  0 66]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       1.00      0.83      0.91        18
#        mixed       0.67      0.80      0.73         5
#       orange       0.86      1.00      0.92        18
#
#     accuracy                           0.90        60
#    macro avg       0.87      0.88      0.87        60
# weighted avg       0.91      0.90      0.90        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 15  0  2]
#  [ 0  0  4  1]
#  [ 0  0  0 18]]
# --------------------------------------------------
#
# Run 6 [32, 32, 32] (Batch size: 16)
# ------------------------------
# Epoch 1, Loss: 56.8131, Accuracy: 50.25%
# Epoch 2, Loss: 36.4865, Accuracy: 71.75%
# Epoch 3, Loss: 32.2131, Accuracy: 77.12%
# Epoch 4, Loss: 26.9848, Accuracy: 81.62%
# Epoch 5, Loss: 23.7142, Accuracy: 84.38%
# Epoch 6, Loss: 21.2425, Accuracy: 85.75%
# Epoch 7, Loss: 20.4746, Accuracy: 87.38%
# Epoch 8, Loss: 18.3845, Accuracy: 87.88%
# Epoch 9, Loss: 19.4165, Accuracy: 85.25%
# Epoch 10, Loss: 16.2953, Accuracy: 89.12%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.92      0.97      0.94        61
#       banana       0.78      0.94      0.85        52
#        mixed       0.89      0.86      0.88        58
#       orange       0.98      0.81      0.89        69
#
#     accuracy                           0.89       240
#    macro avg       0.89      0.90      0.89       240
# weighted avg       0.90      0.89      0.89       240
#
# Confusion Matrix:
# [[59  2  0  0]
#  [ 1 49  1  1]
#  [ 2  6 50  0]
#  [ 2  6  5 56]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.89      0.89      0.89        19
#       banana       0.94      0.89      0.91        18
#        mixed       0.38      0.60      0.46         5
#       orange       0.94      0.83      0.88        18
#
#     accuracy                           0.85        60
#    macro avg       0.79      0.80      0.79        60
# weighted avg       0.88      0.85      0.86        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 16  1  0]
#  [ 1  0  3  1]
#  [ 0  1  2 15]]
# --------------------------------------------------
#
# Run 6 [32, 32, 32] (Batch size: 32)
# ------------------------------
# Epoch 1, Loss: 31.4716, Accuracy: 40.00%
# Epoch 2, Loss: 20.5421, Accuracy: 68.50%
# Epoch 3, Loss: 14.7746, Accuracy: 78.50%
# Epoch 4, Loss: 12.7539, Accuracy: 82.88%
# Epoch 5, Loss: 13.6290, Accuracy: 81.12%
# Epoch 6, Loss: 10.8493, Accuracy: 84.38%
# Epoch 7, Loss: 9.8370, Accuracy: 86.62%
# Epoch 8, Loss: 9.0741, Accuracy: 87.38%
# Epoch 9, Loss: 9.2602, Accuracy: 86.62%
# Epoch 10, Loss: 8.2299, Accuracy: 88.88%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.91      1.00      0.95        61
#       banana       0.85      0.96      0.90        52
#        mixed       0.91      0.88      0.89        58
#       orange       0.98      0.83      0.90        69
#
#     accuracy                           0.91       240
#    macro avg       0.91      0.92      0.91       240
# weighted avg       0.92      0.91      0.91       240
#
# Confusion Matrix:
# [[61  0  0  0]
#  [ 1 50  0  1]
#  [ 3  4 51  0]
#  [ 2  5  5 57]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.89      0.89      0.89        19
#       banana       0.94      0.89      0.91        18
#        mixed       0.40      0.80      0.53         5
#       orange       1.00      0.78      0.88        18
#
#     accuracy                           0.85        60
#    macro avg       0.81      0.84      0.80        60
# weighted avg       0.90      0.85      0.86        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 16  1  0]
#  [ 1  0  4  0]
#  [ 0  1  3 14]]
# --------------------------------------------------
#
# Run 6 [32, 32, 32] (Batch size: 64)
# ------------------------------
# Epoch 1, Loss: 15.7761, Accuracy: 43.88%
# Epoch 2, Loss: 11.2253, Accuracy: 65.75%
# Epoch 3, Loss: 8.4838, Accuracy: 75.75%
# Epoch 4, Loss: 8.1074, Accuracy: 77.38%
# Epoch 5, Loss: 6.8333, Accuracy: 81.50%
# Epoch 6, Loss: 6.3468, Accuracy: 84.12%
# Epoch 7, Loss: 5.8841, Accuracy: 84.88%
# Epoch 8, Loss: 5.6151, Accuracy: 85.62%
# Epoch 9, Loss: 5.0278, Accuracy: 86.75%
# Epoch 10, Loss: 4.7403, Accuracy: 88.75%
#
#  Validation Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.93      0.90      0.92        61
#       banana       0.80      0.87      0.83        52
#        mixed       0.84      0.88      0.86        58
#       orange       0.92      0.86      0.89        69
#
#     accuracy                           0.88       240
#    macro avg       0.87      0.88      0.87       240
# weighted avg       0.88      0.88      0.88       240
#
# Confusion Matrix:
# [[55  3  3  0]
#  [ 1 45  3  3]
#  [ 1  4 51  2]
#  [ 2  4  4 59]]
#
#  Test Set Evaluation
# ----------------------------------------
# Classification Report:
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.94      0.89      0.91        18
#        mixed       0.57      0.80      0.67         5
#       orange       0.89      0.89      0.89        18
#
#     accuracy                           0.88        60
#    macro avg       0.84      0.87      0.85        60
# weighted avg       0.90      0.88      0.89        60
#
# Confusion Matrix:
# [[17  0  2  0]
#  [ 1 16  0  1]
#  [ 0  0  4  1]
#  [ 0  1  1 16]]
# --------------------------------------------------
