# %% [markdown]
# ### Experiment 6: Training Schedule ##
# **Initial Base-Line Run: (With balanced data of 200 images per class)**

# %%
# Import required libraries for data handling, model building, and visualization
import os
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
from torch.utils.data import random_split

# Define paths to your local training and testing image directories
train_path = "../train"
test_path = "../test"

# Define image transformations for training data
transform_train = transforms.Compose([
    transforms.Resize((100, 100)),            # Resize images to 100x100
    transforms.RandomHorizontalFlip(),        # Randomly flip images horizontally for augmentation
    transforms.RandomRotation(15),            # Randomly rotate images by up to ±15 degrees
    transforms.ToTensor(),                    # Convert images to tensors
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)  # Normalize pixel values to range [-1, 1]
])

# Define transformations for test data (no augmentation)
transform_test = transforms.Compose([
    transforms.Resize((100, 100)),            # Resize images to 100x100
    transforms.ToTensor(),                    # Convert to tensor
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)  # Normalize pixel values
])


# Load training and test datasets using folder structure
train_data = ImageFolder(train_path, transform=transform_train)
test_data = ImageFolder(test_path, transform=transform_test)

#For validation, splitting training by 70% and validation by 30%
train_size = int(0.7 * len(train_data))
val_size = len(train_data) - train_size

train_dataset, val_dataset = random_split(train_data, [train_size, val_size])

# Create DataLoader to batch and shuffle the data
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# Print class labels detected from folder names
print("Classes:", train_data.classes)

# Define the CNN architecture
class FruitCNN(nn.Module):
    def __init__(self):
        super(FruitCNN, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),  # First convolutional layer
            nn.ReLU(),                                  # ReLU activation
            nn.MaxPool2d(2),                             # Max pooling to reduce spatial size

            nn.Conv2d(32, 64, kernel_size=3, padding=1), # Second convolutional layer
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1), # Third convolutional layer
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Flatten(),                                # Flatten the output to 1D
            nn.Linear(128 * 12 * 12, 256),                # Fully connected layer
            nn.ReLU(),
            nn.Dropout(0.3),                              # Dropout for regularization
            nn.Linear(256, 4)                             # Output layer for 4 fruit classes
        )

    def forward(self, x):
        return self.model(x)  # Define forward pass

# Use GPU if available, otherwise fallback to CPU
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print("Using device:", device)

# Initialize model, define loss function and optimizer
model = FruitCNN().to(device)
criterion = nn.CrossEntropyLoss()                # Use cross entropy for classification
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Adam optimizer with learning rate 0.001

# Lists to track training accuracy and loss
train_acc = []
train_loss = []
val_acc = []
val_loss = []

# Set number of epochs
epochs = 15

# Training loop
for epoch in range(epochs):
    model.train()  # Set model to training mode
    correct = 0
    total = 0
    running_loss = 0.0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to device

        optimizer.zero_grad()          # Clear previous gradients
        outputs = model(images)        # Forward pass
        loss = criterion(outputs, labels)  # Compute loss
        loss.backward()                # Backward pass
        optimizer.step()               # Update weights

        running_loss += loss.item()    # Accumulate loss
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        total += labels.size(0)        # Total samples
        correct += (predicted == labels).sum().item()  # Correct predictions

    acc = correct / total             # Calculate accuracy
    train_loss.append(running_loss)   # Record loss
    train_acc.append(acc)             # Record accuracy

    #Validation loop
    model.eval()
    val_correct = 0
    val_total = 0
    val_running_loss = 0.0

    with torch.no_grad():
        for val_images, val_labels in val_loader:
            val_images, val_labels = val_images.to(device), val_labels.to(device)
            val_outputs = model(val_images)
            val_loss_batch = criterion(val_outputs, val_labels)
            val_running_loss += val_loss_batch.item()
            _, val_preds = torch.max(val_outputs,1)
            val_total += val_labels.size(0)
            val_correct += (val_preds == val_labels).sum().item()

    epoch_val_acc = val_correct/val_total
    val_acc.append(epoch_val_acc)
    val_loss.append(val_running_loss)


    # Print metrics after each epoch
    print(f"Epoch {epoch+1}, Train Loss: {running_loss:.4f}, Train Acc: {acc:.4f}, "
          f"Val Loss: {val_running_loss:.4f}, Val Acc: {epoch_val_acc:.4f}")

# Evaluation on test set
model.eval()  # Set model to evaluation mode
y_true = []
y_pred = []

# No need to calculate gradients during evaluation
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)  # Get predicted classes
        y_pred.extend(preds.cpu().numpy())  # Store predictions
        y_true.extend(labels.numpy())       # Store actual labels

# Print classification report
print(classification_report(y_true, y_pred, target_names=train_data.classes))

# Plot training accuracy over epochs
plt.plot(train_acc, label='Train Accuracy')
plt.title('Training Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training loss over epochs
plt.plot(train_loss, label='Train Loss')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.plot(train_acc, label='Train Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation loss
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Classes: ['apple', 'banana', 'mixed', 'orange']
# Using device: mps
# Epoch 1, Train Loss: 21.3373, Train Acc: 0.4462, Val Loss: 7.6638, Val Acc: 0.5833
# Epoch 2, Train Loss: 13.6617, Train Acc: 0.7151, Val Loss: 5.8709, Val Acc: 0.7667
# Epoch 3, Train Loss: 11.3460, Train Acc: 0.7760, Val Loss: 5.3047, Val Acc: 0.7667
# Epoch 4, Train Loss: 9.1286, Train Acc: 0.8423, Val Loss: 5.0364, Val Acc: 0.7583
# Epoch 5, Train Loss: 7.2111, Train Acc: 0.8315, Val Loss: 3.9216, Val Acc: 0.8375
# Epoch 6, Train Loss: 8.5463, Train Acc: 0.8441, Val Loss: 3.8460, Val Acc: 0.8292
# Epoch 7, Train Loss: 6.0377, Train Acc: 0.8925, Val Loss: 3.7173, Val Acc: 0.8583
# Epoch 8, Train Loss: 6.3440, Train Acc: 0.8871, Val Loss: 3.8988, Val Acc: 0.8500
# Epoch 9, Train Loss: 5.5283, Train Acc: 0.9086, Val Loss: 3.7639, Val Acc: 0.8375
# Epoch 10, Train Loss: 4.8873, Train Acc: 0.9229, Val Loss: 3.5988, Val Acc: 0.8458
# Epoch 11, Train Loss: 4.2225, Train Acc: 0.9086, Val Loss: 3.9900, Val Acc: 0.8458
# Epoch 12, Train Loss: 3.2789, Train Acc: 0.9444, Val Loss: 3.8302, Val Acc: 0.8583
# Epoch 13, Train Loss: 2.9766, Train Acc: 0.9337, Val Loss: 3.8865, Val Acc: 0.8708
# Epoch 14, Train Loss: 4.7955, Train Acc: 0.9176, Val Loss: 3.3911, Val Acc: 0.8750
# Epoch 15, Train Loss: 3.5986, Train Acc: 0.9444, Val Loss: 3.6999, Val Acc: 0.8708
#               precision    recall  f1-score   support
#
#        apple       0.85      0.89      0.87        19
#       banana       0.94      0.89      0.91        18
#        mixed       0.36      0.80      0.50         5
#       orange       1.00      0.67      0.80        18
#
#     accuracy                           0.82        60
#    macro avg       0.79      0.81      0.77        60
# weighted avg       0.88      0.82      0.83        60

# %% [markdown]
# ### Tuned Run #1:
# **Epoch=15 to Epoch=30**

# %%
# Import required libraries for data handling, model building, and visualization
import os
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
from torch.utils.data import random_split

# Define paths to your local training and testing image directories
train_path = "../train"
test_path = "../test"

# Define image transformations for training data
transform_train = transforms.Compose([
    transforms.Resize((100, 100)),            # Resize images to 100x100
    transforms.RandomHorizontalFlip(),        # Randomly flip images horizontally for augmentation
    transforms.RandomRotation(15),            # Randomly rotate images by up to ±15 degrees
    transforms.ToTensor(),                    # Convert images to tensors
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)  # Normalize pixel values to range [-1, 1]
])

# Define transformations for test data (no augmentation)
transform_test = transforms.Compose([
    transforms.Resize((100, 100)),            # Resize images to 100x100
    transforms.ToTensor(),                    # Convert to tensor
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)  # Normalize pixel values
])


# Load training and test datasets using folder structure
train_data = ImageFolder(train_path, transform=transform_train)
test_data = ImageFolder(test_path, transform=transform_test)

#For validation, splitting training by 70% and validation by 30%
train_size = int(0.7 * len(train_data))
val_size = len(train_data) - train_size

train_dataset, val_dataset = random_split(train_data, [train_size, val_size])

# Create DataLoader to batch and shuffle the data
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# Print class labels detected from folder names
print("Classes:", train_data.classes)

# Define the CNN architecture
class FruitCNN(nn.Module):
    def __init__(self):
        super(FruitCNN, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),  # First convolutional layer
            nn.ReLU(),                                  # ReLU activation
            nn.MaxPool2d(2),                             # Max pooling to reduce spatial size

            nn.Conv2d(32, 64, kernel_size=3, padding=1), # Second convolutional layer
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1), # Third convolutional layer
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Flatten(),                                # Flatten the output to 1D
            nn.Linear(128 * 12 * 12, 256),                # Fully connected layer
            nn.ReLU(),
            nn.Dropout(0.3),                              # Dropout for regularization
            nn.Linear(256, 4)                             # Output layer for 4 fruit classes
        )

    def forward(self, x):
        return self.model(x)  # Define forward pass

# Use GPU if available, otherwise fallback to CPU
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print("Using device:", device)

# Initialize model, define loss function and optimizer
model = FruitCNN().to(device)
criterion = nn.CrossEntropyLoss()                # Use cross entropy for classification
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Adam optimizer with learning rate 0.001

# Lists to track training accuracy and loss
train_acc = []
train_loss = []
val_acc = []
val_loss = []

# Set number of epochs
epochs = 30

# Training loop
for epoch in range(epochs):
    model.train()  # Set model to training mode
    correct = 0
    total = 0
    running_loss = 0.0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to device

        optimizer.zero_grad()          # Clear previous gradients
        outputs = model(images)        # Forward pass
        loss = criterion(outputs, labels)  # Compute loss
        loss.backward()                # Backward pass
        optimizer.step()               # Update weights

        running_loss += loss.item()    # Accumulate loss
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        total += labels.size(0)        # Total samples
        correct += (predicted == labels).sum().item()  # Correct predictions

    acc = correct / total             # Calculate accuracy
    train_loss.append(running_loss)   # Record loss
    train_acc.append(acc)             # Record accuracy

    #Validation loop
    model.eval()
    val_correct = 0
    val_total = 0
    val_running_loss = 0.0

    with torch.no_grad():
        for val_images, val_labels in val_loader:
            val_images, val_labels = val_images.to(device), val_labels.to(device)
            val_outputs = model(val_images)
            val_loss_batch = criterion(val_outputs, val_labels)
            val_running_loss += val_loss_batch.item()
            _, val_preds = torch.max(val_outputs,1)
            val_total += val_labels.size(0)
            val_correct += (val_preds == val_labels).sum().item()

    epoch_val_acc = val_correct/val_total
    val_acc.append(epoch_val_acc)
    val_loss.append(val_running_loss)


    # Print metrics after each epoch
    print(f"Epoch {epoch+1}, Train Loss: {running_loss:.4f}, Train Acc: {acc:.4f}, "
          f"Val Loss: {val_running_loss:.4f}, Val Acc: {epoch_val_acc:.4f}")

# Evaluation on test set
model.eval()  # Set model to evaluation mode
y_true = []
y_pred = []

# No need to calculate gradients during evaluation
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)  # Get predicted classes
        y_pred.extend(preds.cpu().numpy())  # Store predictions
        y_true.extend(labels.numpy())       # Store actual labels

# Print classification report
print(classification_report(y_true, y_pred, target_names=train_data.classes))

# Plot training accuracy over epochs
plt.plot(train_acc, label='Train Accuracy')
plt.title('Training Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training loss over epochs
plt.plot(train_loss, label='Train Loss')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.plot(train_acc, label='Train Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation loss
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Classes: ['apple', 'banana', 'mixed', 'orange']
# Using device: mps
# Epoch 1, Train Loss: 22.4092, Train Acc: 0.4068, Val Loss: 7.2306, Val Acc: 0.6750
# Epoch 2, Train Loss: 13.4231, Train Acc: 0.7240, Val Loss: 6.5302, Val Acc: 0.7208
# Epoch 3, Train Loss: 10.9277, Train Acc: 0.7849, Val Loss: 5.2390, Val Acc: 0.8208
# Epoch 4, Train Loss: 9.6909, Train Acc: 0.7903, Val Loss: 6.0569, Val Acc: 0.7875
# Epoch 5, Train Loss: 8.7525, Train Acc: 0.8100, Val Loss: 4.0993, Val Acc: 0.8417
# Epoch 6, Train Loss: 6.5484, Train Acc: 0.8728, Val Loss: 4.0606, Val Acc: 0.8583
# Epoch 7, Train Loss: 5.4496, Train Acc: 0.9050, Val Loss: 3.8515, Val Acc: 0.9083
# Epoch 8, Train Loss: 6.2198, Train Acc: 0.8602, Val Loss: 4.2011, Val Acc: 0.8792
# Epoch 9, Train Loss: 5.4816, Train Acc: 0.8996, Val Loss: 4.1106, Val Acc: 0.8667
# Epoch 10, Train Loss: 4.1227, Train Acc: 0.9247, Val Loss: 4.3064, Val Acc: 0.9000
# Epoch 11, Train Loss: 4.6761, Train Acc: 0.9068, Val Loss: 4.5807, Val Acc: 0.8833
# Epoch 12, Train Loss: 4.1778, Train Acc: 0.9122, Val Loss: 3.9289, Val Acc: 0.8833
# Epoch 13, Train Loss: 3.8797, Train Acc: 0.9211, Val Loss: 4.0389, Val Acc: 0.9042
# Epoch 14, Train Loss: 3.0012, Train Acc: 0.9373, Val Loss: 5.0443, Val Acc: 0.8875
# Epoch 15, Train Loss: 2.5106, Train Acc: 0.9498, Val Loss: 3.4192, Val Acc: 0.9375
# Epoch 16, Train Loss: 2.3893, Train Acc: 0.9427, Val Loss: 4.1953, Val Acc: 0.9125
# Epoch 17, Train Loss: 2.6251, Train Acc: 0.9498, Val Loss: 5.5657, Val Acc: 0.8417
# Epoch 18, Train Loss: 2.1779, Train Acc: 0.9570, Val Loss: 4.7022, Val Acc: 0.9042
# Epoch 19, Train Loss: 1.9702, Train Acc: 0.9588, Val Loss: 4.4026, Val Acc: 0.9167
# Epoch 20, Train Loss: 1.6594, Train Acc: 0.9677, Val Loss: 5.1607, Val Acc: 0.8875
# Epoch 21, Train Loss: 1.7607, Train Acc: 0.9659, Val Loss: 5.2915, Val Acc: 0.8875
# Epoch 22, Train Loss: 1.8831, Train Acc: 0.9731, Val Loss: 5.3644, Val Acc: 0.9250
# Epoch 23, Train Loss: 5.2138, Train Acc: 0.9122, Val Loss: 5.4917, Val Acc: 0.8417
# Epoch 24, Train Loss: 2.6329, Train Acc: 0.9552, Val Loss: 3.8278, Val Acc: 0.8875
# Epoch 25, Train Loss: 1.1545, Train Acc: 0.9803, Val Loss: 4.9068, Val Acc: 0.9083
# Epoch 26, Train Loss: 0.8892, Train Acc: 0.9803, Val Loss: 4.9130, Val Acc: 0.9125
# Epoch 27, Train Loss: 0.5919, Train Acc: 0.9892, Val Loss: 5.2890, Val Acc: 0.9167
# Epoch 28, Train Loss: 0.8289, Train Acc: 0.9875, Val Loss: 6.2171, Val Acc: 0.8917
# Epoch 29, Train Loss: 0.9190, Train Acc: 0.9767, Val Loss: 6.6865, Val Acc: 0.8917
# Epoch 30, Train Loss: 0.7328, Train Acc: 0.9857, Val Loss: 5.7671, Val Acc: 0.9125
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.89      0.94      0.92        18
#        mixed       0.60      0.60      0.60         5
#       orange       0.94      0.94      0.94        18
#
#     accuracy                           0.90        60
#    macro avg       0.85      0.85      0.85        60
# weighted avg       0.90      0.90      0.90        60

# %% [markdown]
# ### Tuned Run #2:
# **Epoch=30 with Learning Rate Scheduler**

# %%
# Import required libraries for data handling, model building, and visualization
import os
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
from torch.utils.data import random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau

# Define paths to your local training and testing image directories
train_path = "../train"
test_path = "../test"

# Define image transformations for training data
transform_train = transforms.Compose([
    transforms.Resize((100, 100)),            # Resize images to 100x100
    transforms.RandomHorizontalFlip(),        # Randomly flip images horizontally for augmentation
    transforms.RandomRotation(15),            # Randomly rotate images by up to ±15 degrees
    transforms.ToTensor(),                    # Convert images to tensors
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)  # Normalize pixel values to range [-1, 1]
])

# Define transformations for test data (no augmentation)
transform_test = transforms.Compose([
    transforms.Resize((100, 100)),            # Resize images to 100x100
    transforms.ToTensor(),                    # Convert to tensor
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)  # Normalize pixel values
])


# Load training and test datasets using folder structure
train_data = ImageFolder(train_path, transform=transform_train)
test_data = ImageFolder(test_path, transform=transform_test)

#For validation, splitting training by 70% and validation by 30%
train_size = int(0.7 * len(train_data))
val_size = len(train_data) - train_size

train_dataset, val_dataset = random_split(train_data, [train_size, val_size])

# Create DataLoader to batch and shuffle the data
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# Print class labels detected from folder names
print("Classes:", train_data.classes)

# Define the CNN architecture
class FruitCNN(nn.Module):
    def __init__(self):
        super(FruitCNN, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),  # First convolutional layer
            nn.ReLU(),                                  # ReLU activation
            nn.MaxPool2d(2),                             # Max pooling to reduce spatial size

            nn.Conv2d(32, 64, kernel_size=3, padding=1), # Second convolutional layer
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1), # Third convolutional layer
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Flatten(),                                # Flatten the output to 1D
            nn.Linear(128 * 12 * 12, 256),                # Fully connected layer
            nn.ReLU(),
            nn.Dropout(0.3),                              # Dropout for regularization
            nn.Linear(256, 4)                             # Output layer for 4 fruit classes
        )

    def forward(self, x):
        return self.model(x)  # Define forward pass

# Use GPU if available, otherwise fallback to CPU
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print("Using device:", device)

# Initialize model, define loss function and optimizer
model = FruitCNN().to(device)
criterion = nn.CrossEntropyLoss()                # Use cross entropy for classification
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Adam optimizer with learning rate 0.001

#Adding in scheduler, once after 3 runs of epoch and it plateau, to start reducing LR by x0.1 with a minimum of 1e-6
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor = 0.1, patience = 3, min_lr=1e-6)

# Lists to track training accuracy and loss
train_acc = []
train_loss = []
val_acc = []
val_loss = []

# Set number of epochs
epochs = 30

# Training loop
for epoch in range(epochs):
    model.train()  # Set model to training mode
    correct = 0
    total = 0
    running_loss = 0.0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to device

        optimizer.zero_grad()          # Clear previous gradients
        outputs = model(images)        # Forward pass
        loss = criterion(outputs, labels)  # Compute loss
        loss.backward()                # Backward pass
        optimizer.step()               # Update weights

        running_loss += loss.item()    # Accumulate loss
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        total += labels.size(0)        # Total samples
        correct += (predicted == labels).sum().item()  # Correct predictions

    acc = correct / total             # Calculate accuracy
    train_loss.append(running_loss)   # Record loss
    train_acc.append(acc)             # Record accuracy

    #Validation loop
    model.eval()
    val_correct = 0
    val_total = 0
    val_running_loss = 0.0

    with torch.no_grad():
        for val_images, val_labels in val_loader:
            val_images, val_labels = val_images.to(device), val_labels.to(device)
            val_outputs = model(val_images)
            val_loss_batch = criterion(val_outputs, val_labels)
            val_running_loss += val_loss_batch.item()
            _, val_preds = torch.max(val_outputs,1)
            val_total += val_labels.size(0)
            val_correct += (val_preds == val_labels).sum().item()

    epoch_val_acc = val_correct/val_total
    val_acc.append(epoch_val_acc)
    val_loss.append(val_running_loss)

    scheduler.step(val_running_loss)

    current_lr = optimizer.param_groups[0]['lr']
    # Print metrics after each epoch
    print(f"Epoch {epoch+1}, LR: {current_lr:.6f}, Train Loss: {running_loss:.4f}, Train Acc: {acc:.4f}, "
      f"Val Loss: {val_running_loss:.4f}, Val Acc: {epoch_val_acc:.4f}")

# Evaluation on test set
model.eval()  # Set model to evaluation mode
y_true = []
y_pred = []

# No need to calculate gradients during evaluation
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)  # Get predicted classes
        y_pred.extend(preds.cpu().numpy())  # Store predictions
        y_true.extend(labels.numpy())       # Store actual labels

# Print classification report
print(classification_report(y_true, y_pred, target_names=train_data.classes))

# Plot training accuracy over epochs
plt.plot(train_acc, label='Train Accuracy')
plt.title('Training Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training loss over epochs
plt.plot(train_loss, label='Train Loss')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.plot(train_acc, label='Train Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation loss
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Classes: ['apple', 'banana', 'mixed', 'orange']
# Using device: mps
# Epoch 1, LR: 0.001000, Train Loss: 22.1289, Train Acc: 0.4713, Val Loss: 6.6786, Val Acc: 0.5875
# Epoch 2, LR: 0.001000, Train Loss: 13.2621, Train Acc: 0.7097, Val Loss: 4.7549, Val Acc: 0.8042
# Epoch 3, LR: 0.001000, Train Loss: 10.1463, Train Acc: 0.8154, Val Loss: 3.8036, Val Acc: 0.8458
# Epoch 4, LR: 0.001000, Train Loss: 8.5916, Train Acc: 0.8405, Val Loss: 2.9101, Val Acc: 0.8667
# Epoch 5, LR: 0.001000, Train Loss: 8.4370, Train Acc: 0.8423, Val Loss: 3.8246, Val Acc: 0.8125
# Epoch 6, LR: 0.001000, Train Loss: 8.5799, Train Acc: 0.8280, Val Loss: 2.9690, Val Acc: 0.8625
# Epoch 7, LR: 0.001000, Train Loss: 7.2470, Train Acc: 0.8799, Val Loss: 2.4334, Val Acc: 0.8792
# Epoch 8, LR: 0.001000, Train Loss: 5.9008, Train Acc: 0.8889, Val Loss: 5.6838, Val Acc: 0.8125
# Epoch 9, LR: 0.001000, Train Loss: 10.0335, Train Acc: 0.8047, Val Loss: 2.8542, Val Acc: 0.8792
# Epoch 10, LR: 0.001000, Train Loss: 6.8685, Train Acc: 0.8692, Val Loss: 2.2925, Val Acc: 0.9000
# Epoch 11, LR: 0.001000, Train Loss: 4.3710, Train Acc: 0.9265, Val Loss: 2.0181, Val Acc: 0.8917
# Epoch 12, LR: 0.001000, Train Loss: 4.0966, Train Acc: 0.9211, Val Loss: 2.1032, Val Acc: 0.9000
# Epoch 13, LR: 0.001000, Train Loss: 3.5553, Train Acc: 0.9409, Val Loss: 2.3322, Val Acc: 0.8958
# Epoch 14, LR: 0.001000, Train Loss: 3.4286, Train Acc: 0.9409, Val Loss: 2.3501, Val Acc: 0.9000
# Epoch 15, LR: 0.000100, Train Loss: 3.4450, Train Acc: 0.9265, Val Loss: 2.8553, Val Acc: 0.8792
# Epoch 16, LR: 0.000100, Train Loss: 2.3851, Train Acc: 0.9570, Val Loss: 2.2760, Val Acc: 0.8958
# Epoch 17, LR: 0.000100, Train Loss: 1.6424, Train Acc: 0.9713, Val Loss: 1.9757, Val Acc: 0.8958
# Epoch 18, LR: 0.000100, Train Loss: 1.6302, Train Acc: 0.9785, Val Loss: 1.9219, Val Acc: 0.9292
# Epoch 19, LR: 0.000100, Train Loss: 1.4999, Train Acc: 0.9767, Val Loss: 2.0350, Val Acc: 0.9000
# Epoch 20, LR: 0.000100, Train Loss: 1.3167, Train Acc: 0.9803, Val Loss: 1.8213, Val Acc: 0.9208
# Epoch 21, LR: 0.000100, Train Loss: 1.4925, Train Acc: 0.9767, Val Loss: 2.1196, Val Acc: 0.9083
# Epoch 22, LR: 0.000100, Train Loss: 1.3116, Train Acc: 0.9803, Val Loss: 2.2010, Val Acc: 0.9125
# Epoch 23, LR: 0.000100, Train Loss: 1.2625, Train Acc: 0.9839, Val Loss: 2.1177, Val Acc: 0.9042
# Epoch 24, LR: 0.000010, Train Loss: 1.0515, Train Acc: 0.9892, Val Loss: 2.0060, Val Acc: 0.9042
# Epoch 25, LR: 0.000010, Train Loss: 1.0749, Train Acc: 0.9821, Val Loss: 1.9312, Val Acc: 0.9083
# Epoch 26, LR: 0.000010, Train Loss: 1.1492, Train Acc: 0.9821, Val Loss: 2.0277, Val Acc: 0.9083
# Epoch 27, LR: 0.000010, Train Loss: 1.1744, Train Acc: 0.9803, Val Loss: 2.1231, Val Acc: 0.9000
# Epoch 28, LR: 0.000001, Train Loss: 0.9363, Train Acc: 0.9857, Val Loss: 1.9235, Val Acc: 0.9083
# Epoch 29, LR: 0.000001, Train Loss: 0.9252, Train Acc: 0.9875, Val Loss: 1.9993, Val Acc: 0.9167
# Epoch 30, LR: 0.000001, Train Loss: 1.0324, Train Acc: 0.9839, Val Loss: 1.9894, Val Acc: 0.9208
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.94      0.89      0.91        18
#        mixed       0.57      0.80      0.67         5
#       orange       0.94      0.94      0.94        18
#
#     accuracy                           0.90        60
#    macro avg       0.85      0.88      0.86        60
# weighted avg       0.91      0.90      0.90        60

# %% [markdown]
# ### Tuned Run #3:
# **Epoch=50 with Learning Rate Scheduler**

# %%
# Import required libraries for data handling, model building, and visualization
import os
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
from torch.utils.data import random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau

# Define paths to your local training and testing image directories
train_path = "../train"
test_path = "../test"

# Define image transformations for training data
transform_train = transforms.Compose([
    transforms.Resize((100, 100)),            # Resize images to 100x100
    transforms.RandomHorizontalFlip(),        # Randomly flip images horizontally for augmentation
    transforms.RandomRotation(15),            # Randomly rotate images by up to ±15 degrees
    transforms.ToTensor(),                    # Convert images to tensors
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)  # Normalize pixel values to range [-1, 1]
])

# Define transformations for test data (no augmentation)
transform_test = transforms.Compose([
    transforms.Resize((100, 100)),            # Resize images to 100x100
    transforms.ToTensor(),                    # Convert to tensor
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)  # Normalize pixel values
])


# Load training and test datasets using folder structure
train_data = ImageFolder(train_path, transform=transform_train)
test_data = ImageFolder(test_path, transform=transform_test)

#For validation, splitting training by 70% and validation by 30%
train_size = int(0.7 * len(train_data))
val_size = len(train_data) - train_size

train_dataset, val_dataset = random_split(train_data, [train_size, val_size])

# Create DataLoader to batch and shuffle the data
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# Print class labels detected from folder names
print("Classes:", train_data.classes)

# Define the CNN architecture
class FruitCNN(nn.Module):
    def __init__(self):
        super(FruitCNN, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),  # First convolutional layer
            nn.ReLU(),                                  # ReLU activation
            nn.MaxPool2d(2),                             # Max pooling to reduce spatial size

            nn.Conv2d(32, 64, kernel_size=3, padding=1), # Second convolutional layer
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1), # Third convolutional layer
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Flatten(),                                # Flatten the output to 1D
            nn.Linear(128 * 12 * 12, 256),                # Fully connected layer
            nn.ReLU(),
            nn.Dropout(0.3),                              # Dropout for regularization
            nn.Linear(256, 4)                             # Output layer for 4 fruit classes
        )

    def forward(self, x):
        return self.model(x)  # Define forward pass

# Use GPU if available, otherwise fallback to CPU
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print("Using device:", device)

# Initialize model, define loss function and optimizer
model = FruitCNN().to(device)
criterion = nn.CrossEntropyLoss()                # Use cross entropy for classification
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Adam optimizer with learning rate 0.001

#Adding in scheduler, once after 3 runs of epoch and it plateau, to start reducing LR by x0.1 with a minimum of 1e-6
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor = 0.1, patience = 3, min_lr=1e-6)

# Lists to track training accuracy and loss
train_acc = []
train_loss = []
val_acc = []
val_loss = []

# Set number of epochs
epochs = 50

# Training loop
for epoch in range(epochs):
    model.train()  # Set model to training mode
    correct = 0
    total = 0
    running_loss = 0.0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to device

        optimizer.zero_grad()          # Clear previous gradients
        outputs = model(images)        # Forward pass
        loss = criterion(outputs, labels)  # Compute loss
        loss.backward()                # Backward pass
        optimizer.step()               # Update weights

        running_loss += loss.item()    # Accumulate loss
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        total += labels.size(0)        # Total samples
        correct += (predicted == labels).sum().item()  # Correct predictions

    acc = correct / total             # Calculate accuracy
    train_loss.append(running_loss)   # Record loss
    train_acc.append(acc)             # Record accuracy

    #Validation loop
    model.eval()
    val_correct = 0
    val_total = 0
    val_running_loss = 0.0

    with torch.no_grad():
        for val_images, val_labels in val_loader:
            val_images, val_labels = val_images.to(device), val_labels.to(device)
            val_outputs = model(val_images)
            val_loss_batch = criterion(val_outputs, val_labels)
            val_running_loss += val_loss_batch.item()
            _, val_preds = torch.max(val_outputs,1)
            val_total += val_labels.size(0)
            val_correct += (val_preds == val_labels).sum().item()

    epoch_val_acc = val_correct/val_total
    val_acc.append(epoch_val_acc)
    val_loss.append(val_running_loss)

    scheduler.step(val_running_loss)

    current_lr = optimizer.param_groups[0]['lr']
    # Print metrics after each epoch
    print(f"Epoch {epoch+1}, LR: {current_lr:.6f}, Train Loss: {running_loss:.4f}, Train Acc: {acc:.4f}, "
      f"Val Loss: {val_running_loss:.4f}, Val Acc: {epoch_val_acc:.4f}")

# Evaluation on test set
model.eval()  # Set model to evaluation mode
y_true = []
y_pred = []

# No need to calculate gradients during evaluation
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)  # Get predicted classes
        y_pred.extend(preds.cpu().numpy())  # Store predictions
        y_true.extend(labels.numpy())       # Store actual labels

# Print classification report
print(classification_report(y_true, y_pred, target_names=train_data.classes))

# Plot training accuracy over epochs
plt.plot(train_acc, label='Train Accuracy')
plt.title('Training Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training loss over epochs
plt.plot(train_loss, label='Train Loss')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.plot(train_acc, label='Train Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation loss
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Classes: ['apple', 'banana', 'mixed', 'orange']
# Using device: mps
# Epoch 1, LR: 0.001000, Train Loss: 21.3313, Train Acc: 0.4516, Val Loss: 9.6279, Val Acc: 0.4833
# Epoch 2, LR: 0.001000, Train Loss: 15.4988, Train Acc: 0.6828, Val Loss: 5.1975, Val Acc: 0.7792
# Epoch 3, LR: 0.001000, Train Loss: 11.3244, Train Acc: 0.7903, Val Loss: 4.0748, Val Acc: 0.8458
# Epoch 4, LR: 0.001000, Train Loss: 9.7576, Train Acc: 0.7975, Val Loss: 4.3346, Val Acc: 0.8125
# Epoch 5, LR: 0.001000, Train Loss: 8.3003, Train Acc: 0.8315, Val Loss: 3.3429, Val Acc: 0.8625
# Epoch 6, LR: 0.001000, Train Loss: 6.6992, Train Acc: 0.8656, Val Loss: 3.7164, Val Acc: 0.8417
# Epoch 7, LR: 0.001000, Train Loss: 6.2205, Train Acc: 0.8763, Val Loss: 3.3763, Val Acc: 0.8792
# Epoch 8, LR: 0.001000, Train Loss: 5.2701, Train Acc: 0.8817, Val Loss: 3.7097, Val Acc: 0.8750
# Epoch 9, LR: 0.000100, Train Loss: 5.2419, Train Acc: 0.8925, Val Loss: 3.8362, Val Acc: 0.8583
# Epoch 10, LR: 0.000100, Train Loss: 4.2389, Train Acc: 0.9176, Val Loss: 3.3456, Val Acc: 0.8833
# Epoch 11, LR: 0.000100, Train Loss: 3.2567, Train Acc: 0.9498, Val Loss: 2.9676, Val Acc: 0.9042
# Epoch 12, LR: 0.000100, Train Loss: 2.9659, Train Acc: 0.9570, Val Loss: 3.1552, Val Acc: 0.9042
# Epoch 13, LR: 0.000100, Train Loss: 2.5669, Train Acc: 0.9570, Val Loss: 3.1305, Val Acc: 0.9083
# Epoch 14, LR: 0.000100, Train Loss: 2.8018, Train Acc: 0.9480, Val Loss: 3.2180, Val Acc: 0.9000
# Epoch 15, LR: 0.000010, Train Loss: 2.7694, Train Acc: 0.9462, Val Loss: 3.0550, Val Acc: 0.9083
# Epoch 16, LR: 0.000010, Train Loss: 2.7565, Train Acc: 0.9570, Val Loss: 3.2614, Val Acc: 0.8958
# Epoch 17, LR: 0.000010, Train Loss: 2.5678, Train Acc: 0.9534, Val Loss: 3.2045, Val Acc: 0.9042
# Epoch 18, LR: 0.000010, Train Loss: 2.0386, Train Acc: 0.9749, Val Loss: 3.1626, Val Acc: 0.9083
# Epoch 19, LR: 0.000001, Train Loss: 2.3471, Train Acc: 0.9516, Val Loss: 3.2057, Val Acc: 0.9000
# Epoch 20, LR: 0.000001, Train Loss: 2.2453, Train Acc: 0.9624, Val Loss: 3.2187, Val Acc: 0.9000
# Epoch 21, LR: 0.000001, Train Loss: 2.3926, Train Acc: 0.9606, Val Loss: 2.9922, Val Acc: 0.9083
# Epoch 22, LR: 0.000001, Train Loss: 2.1821, Train Acc: 0.9642, Val Loss: 3.0815, Val Acc: 0.9125
# Epoch 23, LR: 0.000001, Train Loss: 2.3817, Train Acc: 0.9588, Val Loss: 3.0633, Val Acc: 0.9167
# Epoch 24, LR: 0.000001, Train Loss: 2.1086, Train Acc: 0.9659, Val Loss: 3.1273, Val Acc: 0.9125
# Epoch 25, LR: 0.000001, Train Loss: 2.5155, Train Acc: 0.9552, Val Loss: 3.1784, Val Acc: 0.9000
# Epoch 26, LR: 0.000001, Train Loss: 2.6716, Train Acc: 0.9552, Val Loss: 3.1671, Val Acc: 0.9042
# Epoch 27, LR: 0.000001, Train Loss: 2.4297, Train Acc: 0.9606, Val Loss: 3.2562, Val Acc: 0.9083
# Epoch 28, LR: 0.000001, Train Loss: 2.4262, Train Acc: 0.9552, Val Loss: 3.2414, Val Acc: 0.9000
# Epoch 29, LR: 0.000001, Train Loss: 2.7885, Train Acc: 0.9534, Val Loss: 3.0511, Val Acc: 0.9125
# Epoch 30, LR: 0.000001, Train Loss: 2.6043, Train Acc: 0.9534, Val Loss: 3.1953, Val Acc: 0.9083
# Epoch 31, LR: 0.000001, Train Loss: 2.3609, Train Acc: 0.9642, Val Loss: 3.1278, Val Acc: 0.9125
# Epoch 32, LR: 0.000001, Train Loss: 2.5823, Train Acc: 0.9642, Val Loss: 3.0347, Val Acc: 0.9208
# Epoch 33, LR: 0.000001, Train Loss: 2.5409, Train Acc: 0.9516, Val Loss: 3.3010, Val Acc: 0.8958
# Epoch 34, LR: 0.000001, Train Loss: 2.2427, Train Acc: 0.9642, Val Loss: 3.3005, Val Acc: 0.9125
# Epoch 35, LR: 0.000001, Train Loss: 2.3396, Train Acc: 0.9642, Val Loss: 3.0789, Val Acc: 0.9083
# Epoch 36, LR: 0.000001, Train Loss: 1.8701, Train Acc: 0.9713, Val Loss: 3.2309, Val Acc: 0.9083
# Epoch 37, LR: 0.000001, Train Loss: 2.2145, Train Acc: 0.9642, Val Loss: 3.2387, Val Acc: 0.9125
# Epoch 38, LR: 0.000001, Train Loss: 2.3313, Train Acc: 0.9480, Val Loss: 3.1314, Val Acc: 0.9083
# Epoch 39, LR: 0.000001, Train Loss: 2.3178, Train Acc: 0.9606, Val Loss: 3.2275, Val Acc: 0.9167
# Epoch 40, LR: 0.000001, Train Loss: 2.4342, Train Acc: 0.9642, Val Loss: 3.1666, Val Acc: 0.9125
# Epoch 41, LR: 0.000001, Train Loss: 2.2579, Train Acc: 0.9677, Val Loss: 3.2548, Val Acc: 0.9083
# Epoch 42, LR: 0.000001, Train Loss: 2.3261, Train Acc: 0.9606, Val Loss: 3.1732, Val Acc: 0.9042
# Epoch 43, LR: 0.000001, Train Loss: 2.2785, Train Acc: 0.9606, Val Loss: 3.1204, Val Acc: 0.8958
# Epoch 44, LR: 0.000001, Train Loss: 2.2545, Train Acc: 0.9642, Val Loss: 3.1573, Val Acc: 0.9042
# Epoch 45, LR: 0.000001, Train Loss: 2.3574, Train Acc: 0.9642, Val Loss: 3.2278, Val Acc: 0.9083
# Epoch 46, LR: 0.000001, Train Loss: 2.1712, Train Acc: 0.9713, Val Loss: 3.1365, Val Acc: 0.9042
# Epoch 47, LR: 0.000001, Train Loss: 2.2019, Train Acc: 0.9659, Val Loss: 3.1958, Val Acc: 0.9042
# Epoch 48, LR: 0.000001, Train Loss: 2.1138, Train Acc: 0.9677, Val Loss: 3.2218, Val Acc: 0.9042
# Epoch 49, LR: 0.000001, Train Loss: 2.4245, Train Acc: 0.9552, Val Loss: 3.1191, Val Acc: 0.9125
# Epoch 50, LR: 0.000001, Train Loss: 2.5377, Train Acc: 0.9624, Val Loss: 3.1834, Val Acc: 0.9167
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.89      0.89      0.89        18
#        mixed       0.50      0.60      0.55         5
#       orange       0.89      0.89      0.89        18
#
#     accuracy                           0.87        60
#    macro avg       0.81      0.82      0.81        60
# weighted avg       0.87      0.87      0.87        60

# %% [markdown]
# ### Tuned Run #4:
# **Epoch=50 with Learning Rate Scheduler and Early Stopping**

# %%
# Import required libraries for data handling, model building, and visualization
import os
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
from torch.utils.data import random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau

# Define paths to your local training and testing image directories
train_path = "../train"
test_path = "../test"

# Define image transformations for training data
transform_train = transforms.Compose([
    transforms.Resize((100, 100)),            # Resize images to 100x100
    transforms.RandomHorizontalFlip(),        # Randomly flip images horizontally for augmentation
    transforms.RandomRotation(15),            # Randomly rotate images by up to ±15 degrees
    transforms.ToTensor(),                    # Convert images to tensors
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)  # Normalize pixel values to range [-1, 1]
])

# Define transformations for test data (no augmentation)
transform_test = transforms.Compose([
    transforms.Resize((100, 100)),            # Resize images to 100x100
    transforms.ToTensor(),                    # Convert to tensor
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)  # Normalize pixel values
])


# Load training and test datasets using folder structure
train_data = ImageFolder(train_path, transform=transform_train)
test_data = ImageFolder(test_path, transform=transform_test)

#For validation, splitting training by 70% and validation by 30%
train_size = int(0.7 * len(train_data))
val_size = len(train_data) - train_size

train_dataset, val_dataset = random_split(train_data, [train_size, val_size])

# Create DataLoader to batch and shuffle the data
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# Print class labels detected from folder names
print("Classes:", train_data.classes)

# Define the CNN architecture
class FruitCNN(nn.Module):
    def __init__(self):
        super(FruitCNN, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),  # First convolutional layer
            nn.ReLU(),                                  # ReLU activation
            nn.MaxPool2d(2),                             # Max pooling to reduce spatial size

            nn.Conv2d(32, 64, kernel_size=3, padding=1), # Second convolutional layer
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1), # Third convolutional layer
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Flatten(),                                # Flatten the output to 1D
            nn.Linear(128 * 12 * 12, 256),                # Fully connected layer
            nn.ReLU(),
            nn.Dropout(0.3),                              # Dropout for regularization
            nn.Linear(256, 4)                             # Output layer for 4 fruit classes
        )

    def forward(self, x):
        return self.model(x)  # Define forward pass

# Use GPU if available, otherwise fallback to CPU
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print("Using device:", device)

# Initialize model, define loss function and optimizer
model = FruitCNN().to(device)
criterion = nn.CrossEntropyLoss()                # Use cross entropy for classification
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Adam optimizer with learning rate 0.001

#Adding in scheduler, once after 3 runs of epoch and it plateau, to start reducing LR by x0.1 with a minimum of 1e-6
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor = 0.1, patience = 3, min_lr=1e-6)


#class for Early Stopping
class EarlyStopping:
    #patience is the num of epochs to wait without any changes in val loss before stopping run
    #delta is the delta change/minimum change in val loss to be considered as an improvement
    def __init__(self, patience, delta):
        #declaring variables
        self.patience = patience
        self.delta = delta
        self.best_loss = None
        self.counter = 0
        self.early_stop = False

        #pass in the current epoch's val_loss for evaluation
    def __call__ (self, val_loss):

        #for first run, will take the initial val_loss as the best_loss first
        if self.best_loss is None:
            self.best_loss = val_loss
        #if the current val_loss is better or more than the best val so far, increment self counter for tracking
        elif val_loss > self.best_loss - self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True #if self counter == 5 (5 epoch runs with no improvement) then to set boolean flag to True
        else:
            self.best_loss = val_loss
            self.counter = 0

#instantiating earlystopping class
early_stopping = EarlyStopping(patience=5, delta=0.0001)

# Lists to track training accuracy and loss
train_acc = []
train_loss = []
val_acc = []
val_loss = []

# Set number of epochs
epochs = 50

# Training loop
for epoch in range(epochs):
    model.train()  # Set model to training mode
    correct = 0
    total = 0
    running_loss = 0.0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to device

        optimizer.zero_grad()          # Clear previous gradients
        outputs = model(images)        # Forward pass
        loss = criterion(outputs, labels)  # Compute loss
        loss.backward()                # Backward pass
        optimizer.step()               # Update weights

        running_loss += loss.item()    # Accumulate loss
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        total += labels.size(0)        # Total samples
        correct += (predicted == labels).sum().item()  # Correct predictions

    acc = correct / total             # Calculate accuracy
    train_loss.append(running_loss)   # Record loss
    train_acc.append(acc)             # Record accuracy

    #Validation loop
    model.eval()
    val_correct = 0
    val_total = 0
    val_running_loss = 0.0

    with torch.no_grad():
        for val_images, val_labels in val_loader:
            val_images, val_labels = val_images.to(device), val_labels.to(device)
            val_outputs = model(val_images)
            val_loss_batch = criterion(val_outputs, val_labels)
            val_running_loss += val_loss_batch.item()
            _, val_preds = torch.max(val_outputs,1)
            val_total += val_labels.size(0)
            val_correct += (val_preds == val_labels).sum().item()

    epoch_val_acc = val_correct/val_total
    val_acc.append(epoch_val_acc)
    val_loss.append(val_running_loss)

    scheduler.step(val_running_loss)
    early_stopping(val_running_loss)

    #if early_stopping.early_stop == True, to print
    if early_stopping.early_stop:
        print(f"Early stopping at epoch {epoch+1}")
        break

    current_lr = optimizer.param_groups[0]['lr']
    # Print metrics after each epoch
    print(f"Epoch {epoch+1}, LR: {current_lr:.6f}, Train Loss: {running_loss:.4f}, Train Acc: {acc:.4f}, "
      f"Val Loss: {val_running_loss:.4f}, Val Acc: {epoch_val_acc:.4f}")

# Evaluation on test set
model.eval()  # Set model to evaluation mode
y_true = []
y_pred = []

# No need to calculate gradients during evaluation
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)  # Get predicted classes
        y_pred.extend(preds.cpu().numpy())  # Store predictions
        y_true.extend(labels.numpy())       # Store actual labels

# Print classification report
print(classification_report(y_true, y_pred, target_names=train_data.classes))

# Plot training accuracy over epochs
plt.plot(train_acc, label='Train Accuracy')
plt.title('Training Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training loss over epochs
plt.plot(train_loss, label='Train Loss')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.plot(train_acc, label='Train Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation loss
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Classes: ['apple', 'banana', 'mixed', 'orange']
# Using device: mps
# Epoch 1, LR: 0.001000, Train Loss: 24.1442, Train Acc: 0.3548, Val Loss: 9.3129, Val Acc: 0.5292
# Epoch 2, LR: 0.001000, Train Loss: 17.3197, Train Acc: 0.6111, Val Loss: 6.6177, Val Acc: 0.6958
# Epoch 3, LR: 0.001000, Train Loss: 12.7725, Train Acc: 0.7491, Val Loss: 5.2882, Val Acc: 0.7458
# Epoch 4, LR: 0.001000, Train Loss: 10.9133, Train Acc: 0.7670, Val Loss: 4.9860, Val Acc: 0.8000
# Epoch 5, LR: 0.001000, Train Loss: 8.7590, Train Acc: 0.8495, Val Loss: 4.6676, Val Acc: 0.7917
# Epoch 6, LR: 0.001000, Train Loss: 8.1323, Train Acc: 0.8405, Val Loss: 3.8435, Val Acc: 0.8250
# Epoch 7, LR: 0.001000, Train Loss: 7.0347, Train Acc: 0.8763, Val Loss: 3.8244, Val Acc: 0.8458
# Epoch 8, LR: 0.001000, Train Loss: 7.0871, Train Acc: 0.8548, Val Loss: 3.4035, Val Acc: 0.8542
# Epoch 9, LR: 0.001000, Train Loss: 6.0707, Train Acc: 0.8835, Val Loss: 3.4551, Val Acc: 0.8708
# Epoch 10, LR: 0.001000, Train Loss: 5.9028, Train Acc: 0.8817, Val Loss: 3.9718, Val Acc: 0.8417
# Epoch 11, LR: 0.001000, Train Loss: 4.9540, Train Acc: 0.9140, Val Loss: 3.0091, Val Acc: 0.8750
# Epoch 12, LR: 0.001000, Train Loss: 4.1658, Train Acc: 0.9283, Val Loss: 3.5151, Val Acc: 0.8833
# Epoch 13, LR: 0.001000, Train Loss: 3.8789, Train Acc: 0.9211, Val Loss: 3.7443, Val Acc: 0.8542
# Epoch 14, LR: 0.001000, Train Loss: 4.3791, Train Acc: 0.9176, Val Loss: 4.0938, Val Acc: 0.8500
# Epoch 15, LR: 0.000100, Train Loss: 3.7483, Train Acc: 0.9265, Val Loss: 3.4932, Val Acc: 0.8667
# Early stopping at epoch 16
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.88      0.83      0.86        18
#        mixed       0.38      0.60      0.46         5
#       orange       0.94      0.89      0.91        18
#
#     accuracy                           0.85        60
#    macro avg       0.79      0.80      0.79        60
# weighted avg       0.88      0.85      0.86        60

# %% [markdown]
# ### Tuned Run #5:
# **Epoch=50 with Learning Rate Scheduler and Early Stopping (Patience=8)**

# %%
# Import required libraries for data handling, model building, and visualization
import os
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
from torch.utils.data import random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau

# Define paths to your local training and testing image directories
train_path = "../train"
test_path = "../test"

# Define image transformations for training data
transform_train = transforms.Compose([
    transforms.Resize((100, 100)),            # Resize images to 100x100
    transforms.RandomHorizontalFlip(),        # Randomly flip images horizontally for augmentation
    transforms.RandomRotation(15),            # Randomly rotate images by up to ±15 degrees
    transforms.ToTensor(),                    # Convert images to tensors
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)  # Normalize pixel values to range [-1, 1]
])

# Define transformations for test data (no augmentation)
transform_test = transforms.Compose([
    transforms.Resize((100, 100)),            # Resize images to 100x100
    transforms.ToTensor(),                    # Convert to tensor
    transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)  # Normalize pixel values
])


# Load training and test datasets using folder structure
train_data = ImageFolder(train_path, transform=transform_train)
test_data = ImageFolder(test_path, transform=transform_test)

#For validation, splitting training by 70% and validation by 30%
train_size = int(0.7 * len(train_data))
val_size = len(train_data) - train_size

train_dataset, val_dataset = random_split(train_data, [train_size, val_size])

# Create DataLoader to batch and shuffle the data
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# Print class labels detected from folder names
print("Classes:", train_data.classes)

# Define the CNN architecture
class FruitCNN(nn.Module):
    def __init__(self):
        super(FruitCNN, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),  # First convolutional layer
            nn.ReLU(),                                  # ReLU activation
            nn.MaxPool2d(2),                             # Max pooling to reduce spatial size

            nn.Conv2d(32, 64, kernel_size=3, padding=1), # Second convolutional layer
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1), # Third convolutional layer
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Flatten(),                                # Flatten the output to 1D
            nn.Linear(128 * 12 * 12, 256),                # Fully connected layer
            nn.ReLU(),
            nn.Dropout(0.3),                              # Dropout for regularization
            nn.Linear(256, 4)                             # Output layer for 4 fruit classes
        )

    def forward(self, x):
        return self.model(x)  # Define forward pass

# Use GPU if available, otherwise fallback to CPU
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print("Using device:", device)

# Initialize model, define loss function and optimizer
model = FruitCNN().to(device)
criterion = nn.CrossEntropyLoss()                # Use cross entropy for classification
optimizer = optim.Adam(model.parameters(), lr=0.001)  # Adam optimizer with learning rate 0.001

#Adding in scheduler, once after 3 runs of epoch and it plateau, to start reducing LR by x0.1 with a minimum of 1e-6
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor = 0.1, patience = 3, min_lr=1e-6)


#class for Early Stopping
class EarlyStopping:
    #patience is the num of epochs to wait without any changes in val loss before stopping run
    #delta is the delta change/minimum change in val loss to be considered as an improvement
    def __init__(self, patience, delta):
        #declaring variables
        self.patience = patience
        self.delta = delta
        self.best_loss = None
        self.counter = 0
        self.early_stop = False

        #pass in the current epoch's val_loss for evaluation
    def __call__ (self, val_loss):

        #for first run, will take the initial val_loss as the best_loss first
        if self.best_loss is None:
            self.best_loss = val_loss
        #if the current val_loss is better or more than the best val so far, increment self counter for tracking
        elif val_loss > self.best_loss - self.delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True #if self counter == patience level (xx epoch runs with no improvement) then to set boolean flag to True
        else:
            self.best_loss = val_loss
            self.counter = 0

#instantiating earlystopping class
early_stopping = EarlyStopping(patience=8, delta=0.0001)

# Lists to track training accuracy and loss
train_acc = []
train_loss = []
val_acc = []
val_loss = []

# Set number of epochs
epochs = 50

# Training loop
for epoch in range(epochs):
    model.train()  # Set model to training mode
    correct = 0
    total = 0
    running_loss = 0.0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to device

        optimizer.zero_grad()          # Clear previous gradients
        outputs = model(images)        # Forward pass
        loss = criterion(outputs, labels)  # Compute loss
        loss.backward()                # Backward pass
        optimizer.step()               # Update weights

        running_loss += loss.item()    # Accumulate loss
        _, predicted = torch.max(outputs, 1)  # Get predicted class
        total += labels.size(0)        # Total samples
        correct += (predicted == labels).sum().item()  # Correct predictions

    acc = correct / total             # Calculate accuracy
    train_loss.append(running_loss)   # Record loss
    train_acc.append(acc)             # Record accuracy

    #Validation loop
    model.eval()
    val_correct = 0
    val_total = 0
    val_running_loss = 0.0

    with torch.no_grad():
        for val_images, val_labels in val_loader:
            val_images, val_labels = val_images.to(device), val_labels.to(device)
            val_outputs = model(val_images)
            val_loss_batch = criterion(val_outputs, val_labels)
            val_running_loss += val_loss_batch.item()
            _, val_preds = torch.max(val_outputs,1)
            val_total += val_labels.size(0)
            val_correct += (val_preds == val_labels).sum().item()

    epoch_val_acc = val_correct/val_total
    val_acc.append(epoch_val_acc)
    val_loss.append(val_running_loss)

    scheduler.step(val_running_loss)
    early_stopping(val_running_loss)

    #if early_stopping.early_stop == True, to print
    if early_stopping.early_stop:
        print(f"Early stopping at epoch {epoch+1}")
        break

    current_lr = optimizer.param_groups[0]['lr']
    # Print metrics after each epoch
    print(f"Epoch {epoch+1}, LR: {current_lr:.6f}, Train Loss: {running_loss:.4f}, Train Acc: {acc:.4f}, "
      f"Val Loss: {val_running_loss:.4f}, Val Acc: {epoch_val_acc:.4f}")

# Evaluation on test set
model.eval()  # Set model to evaluation mode
y_true = []
y_pred = []

# No need to calculate gradients during evaluation
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)  # Get predicted classes
        y_pred.extend(preds.cpu().numpy())  # Store predictions
        y_true.extend(labels.numpy())       # Store actual labels

# Print classification report
print(classification_report(y_true, y_pred, target_names=train_data.classes))

# Plot training accuracy over epochs
plt.plot(train_acc, label='Train Accuracy')
plt.title('Training Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training loss over epochs
plt.plot(train_loss, label='Train Loss')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training and validation accuracy
plt.plot(train_acc, label='Train Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation loss
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Classes: ['apple', 'banana', 'mixed', 'orange']
# Using device: mps
# Epoch 1, LR: 0.001000, Train Loss: 24.0818, Train Acc: 0.3446, Val Loss: 9.1691, Val Acc: 0.5250
# Epoch 2, LR: 0.001000, Train Loss: 17.3936, Train Acc: 0.5839, Val Loss: 6.6424, Val Acc: 0.6500
# Epoch 3, LR: 0.001000, Train Loss: 13.4256, Train Acc: 0.7232, Val Loss: 5.3287, Val Acc: 0.7292
# Epoch 4, LR: 0.001000, Train Loss: 11.3268, Train Acc: 0.7714, Val Loss: 4.8710, Val Acc: 0.7917
# Epoch 5, LR: 0.001000, Train Loss: 9.3595, Train Acc: 0.8143, Val Loss: 5.4104, Val Acc: 0.7667
# Epoch 6, LR: 0.001000, Train Loss: 9.6667, Train Acc: 0.8143, Val Loss: 3.7887, Val Acc: 0.8208
# Epoch 7, LR: 0.001000, Train Loss: 8.0228, Train Acc: 0.8375, Val Loss: 3.5813, Val Acc: 0.8125
# Epoch 8, LR: 0.001000, Train Loss: 7.0971, Train Acc: 0.8768, Val Loss: 3.5147, Val Acc: 0.8333
# Epoch 9, LR: 0.001000, Train Loss: 6.3896, Train Acc: 0.8696, Val Loss: 3.8056, Val Acc: 0.8208
# Epoch 10, LR: 0.001000, Train Loss: 5.6601, Train Acc: 0.8732, Val Loss: 3.4871, Val Acc: 0.8417
# Epoch 11, LR: 0.001000, Train Loss: 5.9503, Train Acc: 0.8804, Val Loss: 4.5214, Val Acc: 0.8208
# Epoch 12, LR: 0.001000, Train Loss: 6.0449, Train Acc: 0.8857, Val Loss: 3.6231, Val Acc: 0.8500
# Epoch 13, LR: 0.001000, Train Loss: 4.5821, Train Acc: 0.9179, Val Loss: 3.6627, Val Acc: 0.8333
# Epoch 14, LR: 0.000100, Train Loss: 4.3178, Train Acc: 0.9143, Val Loss: 4.0509, Val Acc: 0.8583
# Epoch 15, LR: 0.000100, Train Loss: 3.7027, Train Acc: 0.9161, Val Loss: 3.2506, Val Acc: 0.8667
# Epoch 16, LR: 0.000100, Train Loss: 2.6860, Train Acc: 0.9482, Val Loss: 3.2891, Val Acc: 0.8792
# Epoch 17, LR: 0.000100, Train Loss: 2.4513, Train Acc: 0.9446, Val Loss: 3.1328, Val Acc: 0.8708
# Epoch 18, LR: 0.000100, Train Loss: 2.4347, Train Acc: 0.9536, Val Loss: 3.3776, Val Acc: 0.8667
# Epoch 19, LR: 0.000100, Train Loss: 2.2544, Train Acc: 0.9607, Val Loss: 3.4729, Val Acc: 0.8667
# Epoch 20, LR: 0.000100, Train Loss: 2.3210, Train Acc: 0.9643, Val Loss: 3.1512, Val Acc: 0.8792
# Epoch 21, LR: 0.000010, Train Loss: 2.2074, Train Acc: 0.9571, Val Loss: 3.2784, Val Acc: 0.8750
# Epoch 22, LR: 0.000010, Train Loss: 2.3084, Train Acc: 0.9643, Val Loss: 3.2863, Val Acc: 0.8667
# Epoch 23, LR: 0.000010, Train Loss: 2.3320, Train Acc: 0.9536, Val Loss: 3.3314, Val Acc: 0.8792
# Epoch 24, LR: 0.000010, Train Loss: 2.0065, Train Acc: 0.9589, Val Loss: 3.1397, Val Acc: 0.8792
# Early stopping at epoch 25
#               precision    recall  f1-score   support
#
#        apple       0.94      0.89      0.92        19
#       banana       0.89      0.89      0.89        18
#        mixed       0.60      0.60      0.60         5
#       orange       0.89      0.94      0.92        18
#
#     accuracy                           0.88        60
#    macro avg       0.83      0.83      0.83        60
# weighted avg       0.88      0.88      0.88        60
